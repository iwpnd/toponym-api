# %%
import requests

# %%
word = "Beograd"
language = "Croatian"
payload = {"word":  word, "language": language}
url = 'http://127.0.0.1:8000/api/v1/toponym/'

response = requests.post(url, json=payload)
response.json()
# Out:
# {'word': 'Beograd',
#  'toponyms': {'nominative': ['Beograd'],
#   'genitive': ['Beograda'],
#   'dative': ['Beogradu'],
#   'accusative': ['Beograda'],
#   'locative': ['Beogradu'],
#   'instrumental': ['Beogradom']}}

# %%
word = "Beograd"
language = "Croatian"
payload = {"word":  word, "language": language}
url = "http://127.0.0.1:8000/api/v1/topodict/recipe"

response = requests.post(url, json=payload)
response.json()
# Out:
# {'language': 'Croatian',
#  'word': 'Beograd',
#  'longest_ending': 'd',
#  'recipe': {'nominative': [[''], 0],
#   'genitive': [['a'], 0],
#   'dative': [['u'], 0],
#   'accusative': [['a'], 0],
#   'locative': [['u'], 0],
#   'instrumental': [['om'], 0]}}

# %%
url = 'http://127.0.0.1:8000/api/v1/languages'
response = requests.get(url)
response.json()
# Out:
# {'croatian': 'hr',
#  'russian': 'ru',
#  'ukrainian': 'uk',
#  'romanian': 'ro',
#  'latvian': 'lv',
#  'hungarian': 'hu',
#  'greek': 'el',
#  'polish': 'pl'}

# %%
url = 'http://127.0.0.1:8000/api/v1/topodict/polish/ac'

response = requests.get(url)
response.json()
# Out:
# {'language': 'polish',
#  'ending': 'ac',
#  'recipe': {'nominative': [[''], 0],
#   'genitive': [['a', 'u'], 0],
#   'dative': [['owi'], 0],
#   'accusative': [[''], 0],
#   'instrumental': [['em'], 0],
#   'locative': [['u'], 0]}}

# %%
url = 'http://127.0.0.1:8000/api/v1/topodict/polish'

response = requests.get(url)
response.json()
# Out:
# {'language': 'polish',
#  'topodictionary': {'a': {'nominative': [[''], 0],
#    'genitive': [['y', 'i', 'ej', 'ów'], 1],
#    'dative': [['i', 'ie', 'ej', 'om'], 1],
#    'accusative': [['a', 'ę', 'ą'], 1],
#    'instrumental': [['ą', 'ami'], 1],
#    'locative': [['i', 'ie', 'y', 'ej', 'ach'], 1]},
#   'ła': {'nominative': [[''], 0],
#    'genitive': [['ły', 'eł', 'łej', 'ła'], 2],
#    'dative': [['łom', 'łej', 'lej', 'le'], 2],
#    'accusative': [['a', 'ą'], 1],
#    'instrumental': [['lą', 'łą', 'łami'], 2],
#    'locative': [['łej', 'łach', 'le'], 2]},
#   'ac': {'nominative': [[''], 0],
#    'genitive': [['a', 'u'], 0],
#    'dative': [['owi'], 0],
#    'accusative': [[''], 0],
#    'instrumental': [['em'], 0],
#    'locative': [['u'], 0]},
#   'ak': {'nominative': [[''], 0],
#    'genitive': [['a', 'u'], 0],
#    'dative': [['owi'], 0],
#    'accusative': [[''], 0],
#    'instrumental': [['iem'], 0],
#    'locative': [['u'], 0]},
#   'am': {'nominative': [[''], 0],
# ...

# %%
url = 'https://toponym.iwpnd.pw/api/v1/topodict/croatian'

# %%
# %%time
response = requests.get(url)
response.json()
# Out:
# CPU times: user 19.4 ms, sys: 2.81 ms, total: 22.2 ms
# Wall time: 355 ms
# {'_default': {'nominative': [[''], 0],
#   'genitive': [[''], 0],
#   'dative': [[''], 0],
#   'accusative': [[''], 0],
#   'locative': [[''], 0],
#   'instrumental': [[''], 0]},
#  'a': {'nominative': [[''], 0],
#   'genitive': [['e'], 1],
#   'dative': [['i'], 1],
#   'accusative': [['u'], 1],
#   'locative': [['i'], 1],
#   'instrumental': [['om'], 1]},
#  'b': {'nominative': [[''], 0],
#   'genitive': [['a'], 0],
#   'dative': [['u'], 0],
#   'accusative': [['a'], 0],
#   'locative': [['u'], 0],
#   'instrumental': [['om'], 0]},
#  'c': {'nominative': [[''], 0],
#   'genitive': [['ca'], 2],
#   'dative': [['cu'], 2],
#   'accusative': [['ca'], 2],
#   'locative': [['cu'], 2],
#   'instrumental': [['cem'], 2]},
#  'd': {'nominative': [[''], 0],
#   'genitive': [['a'], 0],
#   'dative': [['u'], 0],
#   'accusative': [['a'], 0],
#   'locative': [['u'], 0],
#   'instrumental': [['om'], 0]},
# ...
